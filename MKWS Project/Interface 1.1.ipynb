# %%
import tkinter as tk

class Application(tk.Frame):
    def start(self):
        print('hi there, everyone!')

    def createWidgets(self):
        self.QUIT = tk.Button(self)
        self.QUIT["text"] = "QUIT"
        self.QUIT["fg"]   = "red"
        self.QUIT["command"] =  self.quit
        self.QUIT.grid(row=0, column=0)
        #self.QUIT.pack({"side": "left"})

        self.hi_there = tk.Button(self)
        self.hi_there["text"] = "START",
        self.hi_there["command"] = self.start

        #self.hi_there.pack({"side": "left"})
        self.hi_there.grid(row=0, column=1)
        
    def createMyWidgets(self):
        
        
        
        
        self.lblFuel = tk.Label(self, text='Fuel:')
        self.lblFuel.grid(row=1, column=0)
        
        self.lblOxidiser = tk.Label(self, text='Oxidiser:')
        self.lblOxidiser.grid(row=1, column=5, padx=50)
        
        
        self.v1 = tk.StringVar()
        self.eCH4 = tk.Entry(self, textvariable = self.v1, width = 8)
        self.eCH4.grid(row=2, column=1)
        
        CheckVar1 = tk.IntVar()
        CheckVar2 = tk.IntVar()
        self.cbCH4 = tk.Checkbutton(self, text = "CH4", variable = CheckVar1, \
                         onvalue = 1, offvalue = 0, height=2, \
                         width = 5, justify = 'left')
        self.cbCH4.grid(row=2, column=0)
        

        self.v1.set("1")
        s1 = self.v1.get()

        v2 = tk.StringVar()
        self.eC2H6 = tk.Entry(self, textvariable = v2, width = 8)
        self.eC2H6.grid(row=3, column=1)
    

        v2.set("0")
        s2 = v2.get()

        self.cbC2H6 = tk.Checkbutton(self, text = "C2H6", variable = CheckVar2, \
                         onvalue = 1, offvalue = 0, height=2, \
                         width = 5, justify = 'left')
        self.cbC2H6.grid(row=3, column=0)
        
        
        
  

    def __init__(self, master=None):
        tk.Frame.__init__(self, master)
        self.grid()
        self.createWidgets()
        self.createMyWidgets()

root = tk.Tk()

root.title("Combustor")
root.geometry("500x200")

app = Application(master=root)
app.mainloop()
root.destroy()
